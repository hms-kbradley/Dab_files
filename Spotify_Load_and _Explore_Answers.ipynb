# %%
#!pip install requests
#!pip install pandas
#!pip install io

import requests
import pandas as pd
from io import StringIO
import matplotlib.pyplot as plt

# %%
# Construct the export URL
url = 'https://docs.google.com/spreadsheets/d/1t7EUQ6zAd-Y5kDK7qbyxmJzYX6CwJUdpG9_I8-nAYhs/export?format=csv&gid=149563190'

# Fetch the CSV data
response = requests.get(url)
data = response.content

# Read the CSV data into a DataFrame
df = pd.read_csv(StringIO(data.decode('utf-8')))

#fix this column
df['streams'] = pd.to_numeric(df['streams'], errors='coerce')

# %%
# Show the first 5 rows
df.head(5)
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts      streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
# Summary statistics
df.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts       streams  \
# count            953.000000         953.000000  9.520000e+02
# mean            5200.124869          12.009444  5.141374e+08
# std             7897.608990          19.575992  5.668569e+08
# min               31.000000           0.000000  2.762000e+03
# 25%              875.000000           0.000000  1.416362e+08
# ...

# %%
# Check for null values
df.isnull().sum()
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  1
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %%
# Sort and filter the top 5 most danceable songs
top_dancability = df.sort_values('danceability_%', ascending = False).head(5)
bottom_dancability = df.sort_values('danceability_%', ascending = True).head(5)
top_dancability
# Out:
#               track_name           artist(s)_name  artist_count  \
# 595                 Peru  Ed Sheeran, Fireboy DML             2
# 224              Players                Coi Leray             1
# 250  The Real Slim Shady                   Eminem             1
# 423    Super Freaky Girl              Nicki Minaj             1
# 702            Starlight                     Dave             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 595           2021              12            23                  2999
# 224           2022              11            30                  4096
# 250           2000               1             1                 20763
# 423           2022               8            12                  4827
# 702           2022               3             3                  1856
#
#      in_spotify_charts       streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
df_sorted_50 = df.sort_values(by='streams', ascending=False).head(50)
pd.options.display.float_format = '{:.2f}'.format

# %%
pd.options.display.float_format = '{:.2f}'.format
# Out:
#                                         track_name  \
# 55                                 Blinding Lights
# 179                                   Shape of You
# 86                               Someone You Loved
# 620                                   Dance Monkey
# 41   Sunflower - Spider-Man: Into the Spider-Verse
# 162                                      One Dance
# 84                       STAY (with Justin Bieber)
# 140                                       Believer
# 725                                         Closer
# 48                                         Starboy
# 138                                        Perfect
# 71                                      Heat Waves
# 14                                       As It Was
# 693                                          Se��o
# 324                           Say You Won't Let Go
# 128                           lovely - Bonus Track
# 127                               Watermelon Sugar
# ...

# %%
# Create a basic line plot
df_sorted = df.sort_values(by='streams', ascending=False).head(10)

#plt.plot(df_sorted['track_name'], df_sorted['streams'])
plt.bar(df_sorted['track_name'], df_sorted['streams'])
plt.title('Top 10 Most Streamed Spotify Songs of 2023')
plt.xlabel('Track Name')
plt.ylabel('Streams (in millions)')
plt.xticks(rotation=90)
plt.show()
